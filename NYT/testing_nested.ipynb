# %%
import json
import pandas as pd
from pandas.io.json import json_normalize #package for flattening json in pandas df

with open('./data.json') as data_file:    
    data = json.load(data_file)

# %%
df = json_normalize(data)

df.head()
# Out:
#   07c0baf9188830fe2252b51bbe7864a74b568681.author  \
# 0                                    Ree Drummond
#
#   07c0baf9188830fe2252b51bbe7864a74b568681.category  \
# 0                    Advice, How-To & Miscellaneous
#
#   07c0baf9188830fe2252b51bbe7864a74b568681.date  \
# 0                                    2019-12-08
#
#   07c0baf9188830fe2252b51bbe7864a74b568681.title  \
# 0      The Pioneer Woman Cooks: The New Frontier
#
#   07c0baf9188830fe2252b51bbe7864a74b568681.weeks_on_list  \
# 0                                            5 weeks
#
#   08a346fc5fda375ab78493e655b3c22e3f6b2276.author  \
# 0                                    J.K. Rowling
#
#   08a346fc5fda375ab78493e655b3c22e3f6b2276.category  \
# 0                                 Children’s Series
#
#   08a346fc5fda375ab78493e655b3c22e3f6b2276.date  \
# 0                                    2019-12-08
#
#   08a346fc5fda375ab78493e655b3c22e3f6b2276.title  \
# 0                                   Harry Potter
#
#   08a346fc5fda375ab78493e655b3c22e3f6b2276.weeks_on_list  \
# 0                                          557 weeks
#
#                            ...                            \
# 0                          ...
#
#   f0705cccc0be2dca66efcd2ab8a25dc7af44d08c.author  \
# 0                                       Lee Child
#
#   f0705cccc0be2dca66efcd2ab8a25dc7af44d08c.category  \
# 0                                 Hardcover Fiction
#
#   f0705cccc0be2dca66efcd2ab8a25dc7af44d08c.date  \
# 0                                    2019-12-08
#
#   f0705cccc0be2dca66efcd2ab8a25dc7af44d08c.title  \
# 0                                      Blue Moon
#
#   f0705cccc0be2dca66efcd2ab8a25dc7af44d08c.weeks_on_list  \
# 0                                            4 weeks
#
#   fb344d3e9eb679f7a285581a94c433b542d06c09.author  \
# 0                                  Brian Kilmeade
#
#   fb344d3e9eb679f7a285581a94c433b542d06c09.category  \
# 0                              Hardcover Nonfiction
#
#   fb344d3e9eb679f7a285581a94c433b542d06c09.date  \
# 0                                    2019-12-08
#
#   fb344d3e9eb679f7a285581a94c433b542d06c09.title  \
# 0             Sam Houston And The Alamo Avengers
#
#   fb344d3e9eb679f7a285581a94c433b542d06c09.weeks_on_list
# 0                                            3 weeks
#
# [1 rows x 225 columns]
